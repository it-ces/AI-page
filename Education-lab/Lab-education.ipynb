# %%
import pandas as pd

# %%
df = pd.read_csv("pib2.tsv", encoding='latin1', sep='\t')

# %%
df = pd.read_excel("base.xlsx")

# %%
df
# Out:
#     Código Departamento (DIVIPOLA)  \
# 0                              NaN
# 1                             91.0
# 2                              5.0
# 3                             81.0
# 4                              8.0
# 5                             11.0
# 6                             13.0
# 7                             15.0
# 8                             17.0
# 9                             18.0
# 10                            85.0
# 11                            19.0
# 12                            20.0
# 13                            27.0
# 14                            23.0
# 15                            25.0
# 16                            94.0
# 17                            95.0
# 18                            41.0
# 19                            44.0
# 20                            47.0
# 21                            50.0
# 22                            52.0
# 23                            54.0
# 24                            86.0
# ...

# %%
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
df.to_csv("Dpto-gdps.csv")

# %%
base = pd.read_csv("Dpto-gdps.csv")

# %%
base
# Out:
#     Unnamed: 0  Código Departamento (DIVIPOLA)  \
# 0            0                             NaN
# 1            1                           91.00
# 2            2                            5.00
# 3            3                           81.00
# 4            4                            8.00
# 5            5                           11.00
# 6            6                           13.00
# 7            7                           15.00
# 8            8                           17.00
# 9            9                           18.00
# 10          10                           85.00
# 11          11                           19.00
# 12          12                           20.00
# 13          13                           27.00
# 14          14                           23.00
# 15          15                           25.00
# 16          16                           94.00
# 17          17                           95.00
# 18          18                           41.00
# ...
